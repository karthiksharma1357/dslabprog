# %%
# Create a Node class to create a node
class Node:
	def __init__(self, data):
		self.data = data
		self.next = None
class LinkedList:
	def __init__(self):
		self.head = None
	def iob(self, data):
		nN = Node(data)
		if self.head is None:
			self.head = nN
			return
		else:
			nN.next = self.head
			self.head = nN
	def iai(self, data, index):
		nN = Node(data)
		cN = self.head
		position = 0
		if position == index:
			self.iob(data)
		else:
			while(cN != None and position+1 != index):
				position = position+1
				cN = cN.next

			if cN != None:
				nN.next = cN.next
				cN.next = nN
			else:
				print("Index not present")

	def iae(self, data):
		nN = Node(data)
		if self.head is None:
			self.head = nN
			return

		cN = self.head
		while(cN.next):
			cN = cN.next

		cN.next = nN
	def un(self, val, index):
		cN = self.head
		position = 0
		if position == index:
			cN.data = val
		else:
			while(cN != None and position != index):
				position = position+1
				cN = cN.next

			if cN != None:
				cN.data = val
			else:
				print("Index not present")

	def rfn(self):
		if(self.head == None):
			return

		self.head = self.head.next
	def rln(self):

		if self.head is None:
			return

		cN = self.head
		while(cN.next.next):
			cN = cN.next

		cN.next = None
	def rai(self, index):
		if self.head == None:
			return

		cN = self.head
		position = 0
		if position == index:
			self.remove_first_node()
		else:
			while(cN != None and position+1 != index):
				position = position+1
				cN = cN.next

			if cN != None:
				cN.next = cN.next.next
			else:
				print("Index not present")
	def rnd(self, data):
		cN = self.head

		if cN.data == data:
			self.remove_first_node()
			return

		while(cN != None and cN.next.data != data):
			cN = cN.next

		if cN == None:
			return
		else:
			cN.next = cN.next.next
	def sizeOfLL(self):
		size = 0
		if(self.head):
			cN = self.head
			while(cN):
				size = size+1
				cN = cN.next
			return size
		else:
			return 0
	def printLL(self):
		cN = self.head
		while(cN):
			print(cN.data)
			cN = cN.next
LL1=LinkedList()
LL1.iob(9)
LL1.iob(5)
LL1.iob(3)
LL1.iob(2)
LL1.iae(17)
LL1.iae(16)
LL1.iai(14,2)
LL1.iai(21,3)
print("Linked list after insertion operations")
LL1.printLL()
LL1.un(55,6)
LL1.rfn()
LL1.rln()
LL1.rai(2)
print("Linked list after deletion operations")
LL1.printLL()
print("size of linked list")
LL1.sizeOfLL()
# Out:
# Linked list after insertion operations
# 2
# 3
# 14
# 21
# 5
# 9
# 17
# 16
# Linked list after deletion operations
# 3
# 14
# 5
# 9
# 55
# size of linked list
# 5
